# %%
import gymnasium as gym
import beamng_gym

env = gym.make('BeamNG-v0')
# Out:
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_0d45137b'
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_e8430f5b'
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_f72a2a22'
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_fe785266'
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_15312924'
# Cannot close shared memory. Original error: [Errno 2] No such file or directory: '/psm_d4bdc234'
# Lidar center_lidar vertical resolution: 32
# Lidar back_lidar vertical resolution: 32
# Camera center_camera resolution: [640, 480]
# Camera back_camera resolution: [1280, 720]
# ======= Action Space =======
# Box([ 0.  0. -1.], 1.0, (3,), float32)
# ======= Observation Space =======
# camera_0: Box(0, 255, (480, 640, 4), uint8)
# camera_1: Box(0, 255, (720, 1280, 4), uint8)
# ...

# %%
obs, info = env.reset()
# Out:
# /media/hestia-22/data_hdd/BeamNG/beamng-gym/env/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
observation, reward, done, info = env.step([1.0, 0, 0])

# %%
camera_0 = observation['camera_0']
camera_1 = observation['camera_1']
# plot the image
import matplotlib.pyplot as plt
plt.imshow(camera_0)
plt.show()
plt.imshow(camera_1)
plt.show()
